# %%
# !wget http://clouds.iec-uit.com/ids/ciciot2023.csv
# Out:
# --2024-08-06 16:16:30--  http://clouds.iec-uit.com/ids/ciciot2023.csv
# Resolving clouds.iec-uit.com (clouds.iec-uit.com)... 103.153.254.47
# Connecting to clouds.iec-uit.com (clouds.iec-uit.com)|103.153.254.47|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 280418104 (267M) [text/csv]
# Saving to: ‘ciciot2023.csv’
#
# ciciot2023.csv      100%[===================>] 267.43M  9.63MB/s    in 29s
#
# 2024-08-06 16:17:00 (9.14 MB/s) - ‘ciciot2023.csv’ saved [280418104/280418104]

# %%
import pandas as pd
data=pd.read_csv("ciciot2023.csv")

# %%
data
# Out:
#         flow_duration  Header_Length  Protocol Type  Duration         Rate  \
# 0            1.544575     2247048.00           6.00     64.00   967.208942
# 1            0.106292      119847.60           6.00     75.80   707.484659
# 2            7.539975      520790.50           6.00     64.00    65.848973
# 3           15.862977      655813.30           7.10    113.30    45.362688
# 4            3.112777      168876.60           5.50     63.60    47.341011
# ...               ...            ...            ...       ...          ...
# 956559       2.697086     1274704.14          16.83     63.36   845.002338
# 956560       0.189456      260888.04          17.00     67.82  2473.656915
# 956561       0.139525      251870.56          17.00     64.00  3332.259203
# 956562       1.598917      977355.72          16.83     63.36  1103.218355
# 956563       0.147302      261100.20          17.00     64.00  3311.793799
#
# ...

# %%
# df là DataFrame của bạn
data = data.dropna(axis=1, how='all')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956564 entries, 0 to 956563
# Data columns (total 47 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   flow_duration    956564 non-null  float64
#  1   Header_Length    956564 non-null  float64
#  2   Protocol Type    956564 non-null  float64
#  3   Duration         956564 non-null  float64
#  4   Rate             956564 non-null  float64
#  5   Srate            956564 non-null  float64
#  6   Drate            956564 non-null  float64
#  7   fin_flag_number  956564 non-null  float64
#  8   syn_flag_number  956564 non-null  float64
#  9   rst_flag_number  956564 non-null  float64
#  10  psh_flag_number  956564 non-null  float64
#  11  ack_flag_number  956564 non-null  float64
#  12  ece_flag_number  956564 non-null  float64
#  13  cwr_flag_number  956564 non-null  float64
#  14  ack_count        956564 non-null  float64
#  15  syn_count        956564 non-null  float64
# ...

# %%
from data_work import processed
last=processed(data,"label")

# %%
last
# Out:
#         label  flow_duration  Header_Length  Protocol Type  Duration    Rate  \
# 0           1              0              0             21       731  447969
# 1           5              0           3617            327       731  273023
# 2           6              0           3617            327       731   94436
# 3           6              0           3617            327       731  457332
# 4           5         286179           8638            327       731  241690
# ...       ...            ...            ...            ...       ...     ...
# 956559      0         398598          64916            647       340  599737
# 956560     11              0              0           2507       731  413708
# 956561      4              0           3617            327       731   11892
# 956562     10         162555         111870           1373      1022  737314
# 956563      4          88396           4163            327       731  257468
#
# ...

# %%
last.to_csv("ciciot2023_processed.csv",index=False)
